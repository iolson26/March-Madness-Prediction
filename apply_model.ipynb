# %%
import pickle
import pandas as pd

# load model bundle
with open('game_predictor_forest.pkl', 'rb') as file:
    bundle = pickle.load(file)

model = bundle["model"]
scaler = bundle["scaler"]
feature_names = bundle["feature_names"]

# load and prep data
march_madness_games = pd.read_csv('23-24MM Games&Stats.csv')

march_madness_games = march_madness_games.drop(columns=[
    "GameID", "Date", "Year",
    "Home_team", "Away_Team",
    "Away_Winner?", "Home_Seed", "Away_Seed",
    "Home Win %", "Away Win %"
])

# enforce correct feature order
march_madness_games = march_madness_games[feature_names]

# scale using trained scaler
march_madness_games_scaled = scaler.transform(march_madness_games)

# predictions
predictions = model.predict(march_madness_games_scaled)
print(predictions)

# probabilities
probabilities = model.predict_proba(march_madness_games_scaled)
print(probabilities)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 26
#      23 march_madness_games = march_madness_games[feature_names]
#      25 # scale using trained scaler
# ---> 26 march_madness_games_scaled = scaler.transform(march_madness_games)
#      28 # predictions
#      29 predictions = model.predict(march_madness_games_scaled)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/.local/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:1062, in StandardScaler.transform(self, X, copy)
#    1059 check_is_fitted(self)
#    1061 copy = copy if copy is not None else self.copy
# -> 1062 X = validate_data(
#    1063     self,
#    1064     X,
#    1065     reset=False,
#    1066     accept_sparse="csr",
#    1067     copy=copy,
#    1068     dtype=FLOAT_DTYPES,
#    1069     force_writeable=True,
#    1070     ensure_all_finite="allow-nan",
#    1071 )
#    1073 if sparse.issparse(X):
#    1074     if self.with_mean:
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Home_winner?
